# %% [markdown]
# <a href="https://colab.research.google.com/github/keinam53/NumPy_Matplotlib_ScyPy/blob/main/2_Wizualizacje_danych/1_Matplotlib_wprowadzenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Matplotlib - wprowadzenie
# 1. [Wykres liniowy](#1)
# 2. [Tworzenie wielu wykresów](#2)
# 3. [Wykresy słupkowe](#3)
# 4. [Wykresy punktowe](#4)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fig = plt.figure()
fig.show()

# %% [markdown]
# ### <a name='1'></a> Wykres liniowy

# %%
_ = plt.plot([0, 1], [0, 3])

# %%
plt.plot([0, 1], [0, 3], label='line', color='green')
plt.xlabel('oś X')
plt.ylabel('oś Y')
plt.title('Wykres')
_ = plt.legend()

# %%
plt.plot([0, 1, 2], [0, 3, 2], label='line', color='green')
plt.xlabel('oś X')
plt.ylabel('oś Y')
plt.title('Wykres')
_ = plt.legend()

# %%
x = np.arange(-3, 3, 0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)


plt.plot(x, x_sin)
_ = plt.plot(x, x_cos)

# %% [markdown]
# ### <a name='2'> </a> Tworzenie wielu wykresów

# %%
plt.subplot(121)
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(122)
plt.plot([0, 1, 2], [4, 1, 5], 'r--')

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(131)
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(132)
plt.plot([0, 1, 2], [4, 1, 5], 'r--')
plt.subplot(133)
plt.plot([0, 1, 2], [4, 1, 5], 'ro')

# %% [markdown]
# ### <a name='3'> </a> Wykresy słupkowe

# %%
plt.bar(x=[0, 1, 2, 3], height=[1.2, 3.2, 1.4, 5.3])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=['a', 'b', 'c', 'd'], height=[1.2, 3.2, 1.4, 5.3])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[1.2, 3.2, 1.4, 5.3])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### <a name='4'> </a> Wykresy punktowe

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)

plt.scatter(x=x1, y=x2)

# %%
x3 = np.random.randn(300) * 50

plt.scatter(x=x1, y=x2, s=x3)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(x=x1, y=x2, s=x3, alpha=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
